# %% [markdown]
# -sandbox
# <h1 style="color:blue">Structured Streaming using Python for capturing NYC taxis data</h1>
#
#  I'd like to compute real-time metrics like peak time of taxi pickups and drop offs, average ride time, most popular boroughs defined by number of taxi orders in NYC, etc.

# %% [markdown]
# -sandbox
# <h2 style="color:blue">Sample Data</h2>
#
# I decided to use some sample taxi data as csv files in /FileStore/tables/streaming/ which I am using to build this application. Let's see how the current folder looks like:

# %%
# %fs ls "/FileStore/tables/streaming/"

# %% [markdown]
# There are 10 CSV files from January 2018 in the directory plus an additional NYC Taxi Zones mapping csv file. Each January file contains 5000 rows.
# Let's see what each CSV file contains by selecting the first one, they all have the same structure.

# %%
# %fs head "/FileStore/tables/streaming/fhv_tripdata_2018_01_1-b3a55.csv"

# %% [markdown]
# Let's have a look at the zones translation file as well.

# %%
# %fs head "/FileStore/tables/streaming/Lookup/NYC_Taxi_zones.csv"

# %% [markdown]
# Each line in the file contains record with 7 fields, out of which only 4 are used for this analysis - `pickup datetime`, `dropoff_time`, `PUlocationID`, `DOlocationID`.

# %% [markdown]
# -sandbox
# <h1 style="color:blue">Batch/Interactive Processing</h1>
#
# Let's investigate the static data first by creating a dataframe on the files and call it staticInputDF

# %%
from pyspark.sql.functions import * 
from pyspark.sql.types import *

inputPath = "/FileStore/tables/streaming/"

staticDataFrame = spark.read.format("csv")\
   .option("header", "true")\
   .option("inferSchema","true") \
   .load(inputPath) \
   .select("Pickup_DateTime", "DropOff_datetime", "PUlocationID", "DOlocationID")

OrderSchema = staticDataFrame.schema 
display(staticDataFrame)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Pickup_DateTime</th><th>DropOff_datetime</th><th>PUlocationID</th><th>DOlocationID</th></tr></thead><tbody><tr><td>2018-01-30T21:20:14.000+0000</td><td>2018-01-30T21:31:20.000+0000</td><td>41</td><td>116</td></tr><tr><td>2018-01-30T21:30:35.000+0000</td><td>2018-01-30T21:37:53.000+0000</td><td>97</td><td>181</td></tr><tr><td>2018-01-30T21:51:29.000+0000</td><td>2018-01-30T22:14:31.000+0000</td><td>181</td><td>36</td></tr><tr><td>2018-01-30T21:53:33.000+0000</td><td>2018-01-30T22:06:41.000+0000</td><td>97</td><td>37</td></tr><tr><td>2018-01-30T21:42:22.000+0000</td><td>2018-01-30T22:04:30.000+0000</td><td>144</td><td>143</td></tr><tr><td>2018-01-30T21:06:23.000+0000</td><td>2018-01-30T21:16:47.000+0000</td><td>237</td><td>141</td></tr><tr><td>2018-01-30T21:33:08.000+0000</td><td>2018-01-30T21:39:48.000+0000</td><td>161</td><td>48</td></tr><tr><td>2018-01-30T21:13:54.000+0000</td><td>2018-01-30T21:56:48.000+0000</td><td>79</td><td>265</td></tr><tr><td>2018-01-30T21:05:59.000+0000</td><td>2018-01-30T21:21:44.000+0000</td><td>64</td><td>15</td></tr><tr><td>2018-01-30T21:32:14.000+0000</td><td>2018-01-30T21:42:10.000+0000</td><td>15</td><td>171</td></tr><tr><td>2018-01-30T21:50:07.000+0000</td><td>2018-01-30T21:59:56.000+0000</td><td>92</td><td>73</td></tr><tr><td>2018-01-30T21:04:18.000+0000</td><td>2018-01-30T21:14:36.000+0000</td><td>126</td><td>213</td
>Brooklyn</td></tr><tr><td>54</td><td>Columbia Street</td><td>Brooklyn</td></tr><tr><td>55</td><td>Coney Island</td><td>Brooklyn</td></tr><tr><td>56</td><td>Corona</td><td>Queens</td></tr><tr><td>56</td><td>Corona</td><td>Queens</td></tr><tr><td>59</td><td>Crotona Park</td><td>Bronx</td></tr><tr><td>60</td><td>Crotona Park East</td><td>Bronx</td></tr><tr><td>61</td><td>Crown Heights North</td><td>Brooklyn</td></tr><tr><td>62</td><td>Crown Heights South</td><td>Brooklyn</td></tr><tr><td>63</td><td>Cypress Hills</td><td>Brooklyn</td></tr><tr><td>65</td><td>Downtown Brooklyn/MetroTech</td><td>Brooklyn</td></tr><tr><td>72</td><td>East Flatbush/Remsen Village</td><td>Brooklyn</td></tr><tr><td>66</td><td>DUMBO/Vinegar Hill</td><td>Brooklyn</td></tr><tr><td>67</td><td>Dyker Heights</td><td>Brooklyn</td></tr><tr><td>68</td><td>East Chelsea</td><td>Manhattan</td></tr><tr><td>73</td><td>East Flushing</td><td>Queens</td></tr><tr><td>69</td><td>East Concourse/Concourse Village</td><td>Bronx</td></tr><tr><td>70</td><td>East Elmhurst</td><td>Queens</td></tr><tr><td>71</td><td>East Flatbus ...

# %% [markdown]
# For the purposes of the analysis we need to combine Pickup_datetime and Dropoff_Datetime in one column - called ServiceTime and adding a new hardcoded column for ServiceType.
# We also need to join our static dataframe with the location mapping table to retrieve the borough and zone names.

# %%
df_Pickup = staticDataFrame.select(col("Pickup_Datetime").alias("ServiceTime"), col("PUlocationID").alias("Location")).withColumn("ServiceType",lit("Pickup"))
df_Dropoff = staticDataFrame.select(col("Dropoff_Datetime").alias("ServiceTime"), col("DOlocationID").alias("Location")).withColumn("ServiceType",lit("DropOff"))

df_final = df_Pickup.union(df_Dropoff)
df_final = df_final.join(df_Location,df_final.Location == df_Location.LocationID, 'left' ).withColumn("ServiceHour", hour("ServiceTime"))

df_final.createOrReplaceTempView("taxi_data")
staticSchema= df_final.schema

display(df_final)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ServiceTime</th><th>Location</th><th>ServiceType</th><th>LocationID</th><th>zone</th><th>borough</th><th>ServiceHour</th></tr></thead><tbody><tr><td>2018-01-30T21:20:14.000+0000</td><td>41</td><td>Pickup</td><td>41</td><td>Central Harlem</td><td>Manhattan</td><td>21</td></tr><tr><td>2018-01-30T21:30:35.000+0000</td><td>97</td><td>Pickup</td><td>97</td><td>Fort Greene</td><td>Brooklyn</td><td>21</td></tr><tr><td>2018-01-30T21:51:29.000+0000</td><td>181</td><td>Pickup</td><td>181</td><td>Park Slope</td><td>Brooklyn</td><td>21</td></tr><tr><td>2018-01-30T21:53:33.000+0000</td><td>97</td><td>Pickup</td><td>97</td><td>Fort Greene</td><td>Brooklyn</td><td>21</td></tr><tr><td>2018-01-30T21:42:22.000+0000</td><td>144</td><td>Pickup</td><td>144</td><td>Little Italy/NoLiTa</td><td>Manhattan</td><td>21</td></tr><tr><td>2018-01-30T21:06:23.000+0000</td><td>237</td><td>Pickup</td><td>237</td><td>Upper East Side South</td><td>Manhattan</td><td>21</td></tr><tr><td>2018-01-30T21:33:08.000+0000</td><td>161</td><td>Pickup</td><td>161</td><td>Midtown Center</td><td>Manhattan</td><td>21</td></tr><tr><td>2018-01-30T21:13:54.000+0000</td><td>79</td><td>Pickup</td><td>79</td><td>East Village</td><td>Manhattan</td><td>21</td></tr><tr><td>2018-01-30T21:05:59.000+0000</td><td>64</td><td>Pickup</td><td>null</td><td>null</td><td>null</td><td>21</td></tr><tr><td>2018-01-30T21:32:14.000+0000</td><td>15</td><td>Pickup</td><td>15</td><td>Bay Terrace/Fort Totten</td><td>Queens</td><td>21</td></tr><tr><td>2018-01-30T21:50:07.000+0000</td><td>92</td><td>Pickup</td><td>92</td><td>Flushing</td><td>Queens</td><td>21</td></tr><tr><td>2018-01-30T21:04:18.000+0000</td><td>126</td><td>Pickup</td><td>126</td><td>Hunts Point</td><td>Bronx</td><td>21</td></tr><tr><td>2018-01-30T21:21:24.000+0000</td><td>41</td><td>Pickup</td><td>41</td><td>Central Harlem</td><td>Manhattan</td><td>21</td></tr><tr><td>2018-01-30T21:33:15.000+0000</td><td>116</td><td>Pickup</td><td>116</td><td>Hamilton Heights</td><td>Manhattan</td><td>21</td></tr><tr><td>2018-01-30T21:49:45.000+0000</td><td>138</td><td>Pickup</td><td>138</td><td>LaGuardia Airport</td><td>Queens</td><td>21</td></tr><tr><td>2018-01-30T21:52:50.000+0000</td><td>230</td><td>Pickup</td><td>230</td><td>Times Sq/Theatre District</td><td>Manhattan</td><td>21</td></tr><tr><td>2018-01-30T21:42:29.000+0000</td><td>254</td><td>Pickup</td><td>254</td><td>Williamsbridge/Olinville</td><td>Bronx</td><td>21</td></tr><tr><td>2018-01-30T21:17:25.000+0000</td><td>79</td><td>Pickup</td><td>79</td><td>East Village</td><td>Manhattan</td><td>21</td></tr><tr><td>2018-01-30T21:41:29.000+0000</td><td>48</td><td>Pickup</td><td>48</td><td>Clinton East</td><td>Manhattan</td><td>21</td></tr><tr><td>2018-01-30T21:43:32.000+0000</td><td>18</td><td>Pickup</td><td>18</td><td>Bedford Park</td><td>Bronx</td><td>21</td></tr><tr><td>2018-01-30T21:45:43.000+0000</td><td>7</td><td>Pickup</td><td>7</td><td>Astoria</td><td>Queens</td><td>21</td></tr><tr><td>2018-01-30T21:30:57.000+0000</td><td>161</td><td>Pickup</td><td>161</td><td>Midtown Center</td><td>Manhattan</td><td>21</td></tr><tr><td>2018-01-30T21:48:50.000+0000</td><td>107</td><td>Pickup</td><td>107</td><td>Gramercy</td><td>Manhattan</td><td>21</td></tr><tr><td>2018-01-30T21:23:24.000+0000</td><td>68</td><td>Pickup</td><td>68</td><td>East Chelsea</td><td>Manhattan</td><td>21</td></tr><tr><td>2018-01-30T21:09:24.000+0000</td><td>244</td><td>Pickup</td><td>244</td><td>Washington Heights South</td><td>Manhattan</td><td>21</td></tr><tr><td>2018-01-30T21:41:32.000+0000</td><td>42</td><td>Pickup</td><td>42</td><td>Central Harlem North</td><td>Manhattan</td><td>21</td></tr><tr><td>2018-01-30T21:57:35.000+0000</td><td>244</td><td>Pickup</td><td>244</td><td>Washington Heights South</td><td>Manhattan</td><td>21</td></tr><tr><td>2018-01-30T21:53:07.000+0000</td><td>79</td><td>Pickup</td><td>79</td><t ...

# %% [markdown]
# d Now we can compute the number of orders per
#  borough, Service hour & day with one hour windows. To do this, we will group by the
#  `ServiceType`, `ServiceHour`, `borough` columns and 1 hour windows over the `Servicetime` column.

# %%
from pyspark.sql.functions import *      # for window() function

staticCountsDF = (
    df_final\
      .selectExpr( "Borough",
                   "ServiceType",
                   "ServiceHour",
                   "ServiceTime").withColumn("Service_Day",  date_format(col("ServiceTime"),'EEEE'))
        .groupBy(
                     col("Service_Day"),
                     col("ServiceType"),
                     col("ServiceHour"),
                     col("Borough"), 
                     window("ServiceTime", "1 hour")) 
                .count()
            )
 
staticCountsDF.cache()

# Register the DataFrame as view 'static_counts'
staticCountsDF.createOrReplaceTempView("static_counts")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Let's check how our static data look like after the grouping - you can notice the one hour window column.

# %%
display(staticCountsDF)

# %% [markdown]
# Now we can directly use SQL to query the table. For example, here are we show a timeline of windowed counts separated by Service type.

# %%
# %sql
select ServiceType,Servicehour, sum(count) as total_count from static_counts group by ServiceType,Servicehour order by Servicehour, ServiceType
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ServiceType</th><th>Servicehour</th><th>total_count</th></tr></thead><tbody><tr><td>DropOff</td><td>0</td><td>4</td></tr><tr><td>Pickup</td><td>0</td><td>4</td></tr><tr><td>DropOff</td><td>1</td><td>8</td></tr><tr><td>Pickup</td><td>1</td><td>6</td></tr><tr><td>DropOff</td><td>2</td><td>4</td></tr><tr><td>Pickup</td><td>2</td><td>5</td></tr><tr><td>DropOff</td><td>3</td><td>7</td></tr><tr><td>Pickup</td><td>3</td><td>6</td></tr><tr><td>DropOff</td><td>4</td><td>9</td></tr><tr><td>Pickup</td><td>4</td><td>10</td></tr><tr><td>DropOff</td><td>5</td><td>11</td></tr><tr><td>Pickup</td><td>5</td><td>7</td></tr><tr><td>DropOff</td><td>6</td><td>6</td></tr><tr><td>Pickup</td><td>6</td><td>10</td></tr><tr><td>DropOff</td><td>7</td><td>9</td></tr><tr><td>Pickup</td><td>7</td><td>7</td></tr><tr><td>DropOff</td><td>8</td><td>7</td></tr><tr><td>Pickup</td><td>8</td><td>8</td></tr><tr><td>DropOff</td><td>9</td><td>6</td></tr><tr><td>Pickup</td><td>9</td><td>9</td></tr><tr><td>DropOff</td><td>10</td><td>7</td></tr><tr><td>Pickup</td><td>10</td><td>7</td></tr><tr><td>DropOff</td><td>11</td><td>7</td></tr><tr><td>Pickup</td><td>11</td><td>7</td></tr><tr><td>DropOff</td><td>12</td><td>10</td></tr><tr><td>Pickup</td><td>12</td><td>7</td></tr><tr><td>DropOff</td><td>13</td><td>9</td></tr><tr><td>Pickup</td><td>13</td><td>3</td></tr><tr><td>DropOff</td><td>14</td><td>5</td></tr><tr><td>Pickup</td><td>14</td><td>3</td></tr><tr><td>DropOff</td><td>15</td><td>1103</td></tr><tr><td>Pickup</td><td>15</td><td>1583</td></tr><tr><td>DropOff</td><td>16</td><td>6990</td></tr><tr><td>Pickup</td><td>16</td><td>10518</td></tr><tr><td>DropOff</td><td>17</td><td>17670</td></tr><tr><td>Pickup</td><td>17</td><td>22520</td></tr><tr><td>DropOff</td><td>18</td><td>10903</td></tr><tr><td>Pickup</td><td>18</td><td>3954</td></tr><tr><td>DropOff</td><td>19</td><td>1838</td></tr><tr><td>Pickup</td><td>19</td><td>91</td></tr><tr><td>DropOff</td><td>20</td><td>107</td></tr><tr><td>DropOff</td><td>21</td><td>4578</td></tr><tr><td>Pickup</td><td>21</td><td>6299</td></tr><tr><td>DropOff</td><td>22</td><td>1756</td></tr><tr><td>Pickup</td><td>22</td><td>1</td></tr><tr><td>DropOff</td><td>23</td><td>18</td></tr></tbody></table></div>

# %% [markdown]
# How about checking the count of pick up orders made in different boroughs per hour

# %%
# %sql
select Borough,Service_Day, sum(count) as total_count from static_counts where Servicetype = 'Pickup' group by Service_Day, Borough
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Borough</th><th>Service_Day</th><th>total_count</th></tr></thead><tbody><tr><td>Manhattan</td><td>Wednesday</td><td>14700</td></tr><tr><td>null</td><td>Wednesday</td><td>7299</td></tr><tr><td>Manhattan</td><td>Thursday</td><td>245</td></tr><tr><td>null</td><td>Tuesday</td><td>1299</td></tr><tr><td>Manhattan</td><td>Sunday</td><td>180</td></tr><tr><td>Brooklyn</td><td>Sunday</td><td>120</td></tr><tr><td>Queens</td><td>Sunday</td><td>100</td></tr><tr><td>Bronx</td><td>Sunday</td><td>55</td></tr><tr><td>Staten Island</td><td>Tuesday</td><td>32</td></tr><tr><td>null</td><td>Friday</td><td>1</td></tr><tr><td>Staten Island</td><td>Thursday</td><td>6</td></tr><tr><td>Queens</td><td>Tuesday</td><td>669</td></tr><tr><td>Brooklyn</td><td>Wednesday</td><td>7480</td></tr><tr><td>Queens</td><td>Wednesday</td><td>3663</td></tr><tr><td>EWR</td><td>Sunday</td><td>1</td></tr><tr><td>Bronx</td><td>Thursday</td><td>40</td></tr><tr><td>null</td><td>Thursday</td><td>76</td></tr><tr><td>Brooklyn</td><td>Tuesday</td><td>1429</td></tr><tr><td>Staten Island</td><td>Wednesday</td><td>179</td></tr><tr><td>Brooklyn</td><td>Thursday</td><td>98</td></tr><tr><td>EWR</td><td>Wednesday</td><td>8</td></tr><tr><td>Manhattan</td><td>Tuesday</td><td>3493</td></tr><tr><td>Queens</td><td>Thursday</td><td>62</td></tr><tr><td>null</td><td>Monday</td><td>48</td></tr><tr><td>Staten Island</td><td>Sunday</td><td>1</td></tr><tr><td>null</td><td>Sunday</td><td>731</td></tr><tr><td>Bronx</td><td>Wednesday</td><td>2532</td></tr><tr><td>Bronx</td><td>Tuesday</td><td>518</td></tr></tbody></table></div>

# %% [markdown]
# Note the most popular pick up locations are Manhattan & Brooklyn and the peak pick up hours are 4 and 5pm

# %% [markdown]
# -sandbox
# <h1 style="color:blue">Stream Processing </h1>
#
# Now that we have analyzed the data interactively, let's convert this to a streaming query that continuously updates as data comes. Since we just have a static set of files, we are going to emulate a stream from them by reading one file at a time, new files will be added to the previous dataframe. The query we have to write is pretty much the same as the interactive query above.

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *  

spark.conf.set("spark.sql.shuffle.partitions", "2") 


streamingDataframe = (
  spark
    .readStream
    .schema(OrderSchema)
    .option("maxFilesPerTrigger", 1) \
    .format("csv")\
    .option("header", "true")\
    .load(inputPath)
)

df_StreamingPickup = streamingDataframe.select(col("Pickup_Datetime").alias("ServiceTime"), col("PUlocationID").alias("Location")).withColumn("ServiceType",lit("Pickup"))
df_StreamingDropoff = streamingDataframe.select(col("Dropoff_Datetime").alias("ServiceTime"), col("DOlocationID").alias("Location")).withColumn("ServiceType",lit("DropOff"))
df_Streamingfinal = df_StreamingPickup.union(df_StreamingDropoff)

# Join Streaming data with location mapping table to retrieve the relevant NYC zone names
df_Streamingfinal = df_Streamingfinal.join(df_Location,df_Streamingfinal.Location == df_Location.LocationID, 'left' ).withColumn("ServiceHour", hour("ServiceTime"))

# # # Same query as staticInputDF
# Same query as staticInputDF
OrderByBoroughPerDayAndServiceType = (                 
  df_Streamingfinal
   .groupBy(
     date_format(col("ServiceTime"),'EEEE').alias("Service_Day"),
       df_Streamingfinal.ServiceType,
       df_Streamingfinal.ServiceHour,
       df_Streamingfinal.borough,
       window(df_Streamingfinal.ServiceTime, "1 hour")
          ) 
    .count()
)

OrderByBoroughPerDayAndServiceType.isStreaming
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>True
# </div>

# %%
spark.conf.set("spark.sql.shuffle.partitions", "2") 

query = (
  OrderByBoroughPerDayAndServiceType
    .writeStream
    .format("memory")        # memory = store in-memory table (for testing only in Spark 2.0)
    .queryName("counts")     # counts = name of the in-memory table           
    .outputMode("complete")  # complete = all the counts should be in the table
    .start()
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from time import sleep
sleep(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
-- select ServiceType, date_format(window.end, "MMM-dd HH:mm") as time, count from counts order by ServiceType, date_format(window.end, "MMM-dd HH:mm")
select ServiceType,Servicehour, sum(count) as total_count from counts group by ServiceType,Servicehour order by Servicehour, ServiceType
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ServiceType</th><th>Servicehour</th><th>total_count</th></tr></thead><tbody><tr><td>DropOff</td><td>0</td><td>1</td></tr><tr><td>DropOff</td><td>1</td><td>3</td></tr><tr><td>Pickup</td><td>1</td><td>2</td></tr><tr><td>DropOff</td><td>2</td><td>2</td></tr><tr><td>Pickup</td><td>2</td><td>2</td></tr><tr><td>DropOff</td><td>3</td><td>3</td></tr><tr><td>Pickup</td><td>3</td><td>3</td></tr><tr><td>DropOff</td><td>4</td><td>4</td></tr><tr><td>Pickup</td><td>4</td><td>4</td></tr><tr><td>DropOff</td><td>5</td><td>7</td></tr><tr><td>Pickup</td><td>5</td><td>5</td></tr><tr><td>DropOff</td><td>6</td><td>2</td></tr><tr><td>Pickup</td><td>6</td><td>2</td></tr><tr><td>DropOff</td><td>7</td><td>2</td></tr><tr><td>Pickup</td><td>7</td><td>2</td></tr><tr><td>DropOff</td><td>8</td><td>5</td></tr><tr><td>Pickup</td><td>8</td><td>7</td></tr><tr><td>DropOff</td><td>9</td><td>5</td></tr><tr><td>Pickup</td><td>9</td><td>6</td></tr><tr><td>DropOff</td><td>10</td><td>3</td></tr><tr><td>Pickup</td><td>10</td><td>4</td></tr><tr><td>DropOff</td><td>11</td><td>5</td></tr><tr><td>Pickup</td><td>11</td><td>5</td></tr><tr><td>DropOff</td><td>12</td><td>6</td></tr><tr><td>Pickup</td><td>12</td><td>2</td></tr><tr><td>DropOff</td><td>13</td><td>5</td></tr><tr><td>DropOff</td><td>14</td><td>2</td></tr><tr><td>DropOff</td><td>15</td><td>631</td></tr><tr><td>Pickup</td><td>15</td><td>905</td></tr><tr><td>DropOff</td><td>16</td><td>5866</td></tr><tr><td>Pickup</td><td>16</td><td>9073</td></tr><tr><td>DropOff</td><td>17</td><td>12429</td></tr><tr><td>Pickup</td><td>17</td><td>14811</td></tr><tr><td>DropOff</td><td>18</td><td>6484</td></tr><tr><td>Pickup</td><td>18</td><td>1529</td></tr><tr><td>DropOff</td><td>19</td><td>813</td></tr><tr><td>Pickup</td><td>19</td><td>1</td></tr><tr><td>DropOff</td><td>20</td><td>63</td></tr><tr><td>DropOff</td><td>21</td><td>2697</td></tr><tr><td>Pickup</td><td>21</td><td>3681</td></tr><tr><td>DropOff</td><td>22</td><td>1009</td></tr><tr><td>Pickup</td><td>22</td><td>1</td></tr><tr><td>DropOff</td><td>23</td><td>8</td></tr></tbody></table></div>

# %%
# %sql select Borough,Service_Day, sum(count) as total_count from counts where Servicetype = 'Pickup' group by Service_Day, Borough
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>